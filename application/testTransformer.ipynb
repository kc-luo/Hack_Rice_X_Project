# %%
from transformer import Transformer
import cv2 as cv
import numpy as np
from helper import *
from ISR.predict import Predictor
from ISR.models import RDN
from ISR.models import RRDN
from PIL import Image

# %%
rdn2 = RDN(arch_params={'C':3, 'D':10, 'G':64, 'G0':64, 'x':2})

# %%
weight2 = './weights/rdn-C3-D10-G64-G064-x2_epoch140.hdf5'

# %%
p = Transformer(rdn2, weight2, True, False)

# %%
img = Image.open("E:\\_Kevin\\Code\\Hack_Rice_X_Project\\application\\321_test.png")
lr_img = np.array(img)[:,:,:3]

# %%
# %time test15 = p.predict(lr_img)
# Out:
# Wall time: 2.97 s

# %%
Image.fromarray(test15)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x494 at 0x1AA1EBF0248>

# %%
from videoEnhancer import VideoEnhancer

# %%
enhancer = VideoEnhancer(p)

# %%
path = "./test_video_10s.mp4"

# %%
# %time enhancer.enhance(path)
# Out:
# 29.854933076861425
# Can't receive frame (stream end?). Exiting ...
# Wall time: 13min 24s
