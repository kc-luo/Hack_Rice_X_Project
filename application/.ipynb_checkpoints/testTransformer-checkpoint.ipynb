# %%
from transformer import Transformer
import cv2
import numpy as np
from ISR.models import RDN
from ISR.models import RRDN
from PIL import Image

# %%
rdn = RDN(arch_params={'C':3, 'D':10, 'G':64, 'G0':64, 'x':2})

# %%
weight_tuned = './weights/rdn-C3-D10-G64-G064-x2_epoch200.hdf5'

# %%
weight_pre = './weights/rdn-C3-D10-G64-G064-x2_epoch140.hdf5'

# %%
p_pre = Transformer(rdn, weight_pre, False, False)

# %%
p_tuned = Transformer(rdn, weight_tuned, False, False)

# %%
img = Image.open("E:\\_Kevin\\Code\\Hack_Rice_X_Project\\application\\321_test.png")
lr_img = np.array(img)[:,:,:3]

# %%
# %time test15 = p_tuned.predict(lr_img)
# Out:
# Wall time: 2.78 s

# %%
denoised = cv2.fastNlMeansDenoisingColored(test15, None, 10, 10, 7, 21)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-404b3c3da740> in <module>
# ----> 1 denoised = cv2.fastNlMeansDenoisingColored(test15, None, 10, 10, 7, 21)
#
# NameError: name 'cv2' is not defined

# %%
Image.fromarray(denoised)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x494 at 0x1122D677708>

# %%
test16 = p_pre.predict(lr_img)

# %%
Image.fromarray(test16)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x494 at 0x1122ED3B148>

# %%
img2 = Image.open("E:\\_Kevin\\Code\\Hack_Rice_X_Project\\application\\2706.png")
tf.image.resize = np.array(img2)[:,:,:3]

# %%
lr_img2 = lr_img2.resize((480,270))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-2fa304b9d430> in <module>
# ----> 1 lr_img2 = lr_img2.resize((480,270))
#
# ValueError: cannot resize this array: it does not own its data

# %%
from videoEnhancer import VideoEnhancer

# %%
enhancer = VideoEnhancer(p)

# %%
path = "./test_video_10s.mp4"

# %%
# %time enhancer.enhance(path)
# Out:
# | |                               #                  | 78 Elapsed Time: 0:10:33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# E:\_Kevin\Code\Hack_Rice_X_Project\application\videoEnhancer.py in enhance(self, path)
#      53                 print("Can't receive frame (stream end?). Exiting ...")
#      54                 break
# ---> 55             frame = self.p.predict(frame)
#      56             # write the flipped frame
#      57             out.write(frame)
#
# E:\_Kevin\Code\Hack_Rice_X_Project\application\transformer.py in predict(self, x)
#      20
#      21     def predict(self, x):
# ---> 22         return self.func(x)
#      23
#      24
#
# E:\_Kevin\Code\Hack_Rice_X_Project\application\transformer.py in <lambda>(x)
#      15         self.expander = model.model.load_weights(weight)
#      16         if sharp_first:
# ...
