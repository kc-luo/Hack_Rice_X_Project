# %%
import numpy as np
from PIL import Image

img = Image.open('sample/baboon.png')
lr_img = np.array(img)

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(lr_img)

# %%
from ISR.models import RDN

# %%
from ISR.models import RDN

rdn = RDN(weights='psnr-small')
sr_img = rdn.predict(lr_img)
Image.fromarray(sr_img)
# Out:
# Downloading data from https://public-asai-dl-models.s3.eu-central-1.amazonaws.com/ISR/rdn-C3-D10-G64-G064-x2/PSNR-driven/rdn-C3-D10-G64-G064-x2_PSNR_epoch134.hdf5
# 10698752/10694096 [==============================] - 6s 1us/step
# <PIL.Image.Image image mode=RGB size=250x240 at 0x24D9A4BECC8>

# %%
plt.imshow(sr_img)

# %%
img2 = Image.open('sample/sandal.jpg')
lr_img2 = np.array(img2)
sr_img2 = rdn.predict(lr_img2)
Image.fromarray(sr_img2)
# Out:
# <PIL.Image.Image image mode=RGB size=700x248 at 0x24D9A518208>

# %%
img3 = Image.open('sample/chalkboard1.png')
lr_img3 = np.array(img3)
plt.imshow(lr_img3)
lr_img3.shape
# Out:
# (240, 427, 4)

# %%
tf.image.resize(
    lr_img3, size, method=ResizeMethod.BILINEAR, preserve_aspect_ratio=False,
    antialias=False, name=None
)

# %%
sr_img3 = rdn.predict(lr_img3)
Image.fromarray(sr_img3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-25c4beddfefa> in <module>
# ----> 1 sr_img3 = rdn.predict(lr_img3)
#       2 Image.fromarray(sr_img3)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\ISR\models\imagemodel.py in predict(self, input_image_array, by_patch_of_size, batch_size, padding_size)
#      57         else:
#      58             lr_img = process_array(input_image_array)
# ---> 59             sr_img = self.model.predict(lr_img)[0]
#      60
#      61         sr_img = process_output(sr_img)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     907         max_queue_size=max_queue_size,
#     908         workers=workers,
# --> 909         use_multiprocessing=use_multiprocessing)
#     910
#     911   def reset_metrics(self):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training_arrays.py in predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     713     batch_size = model._validate_or_infer_batch_size(batch_size, steps, x)
#     714     x, _, _ = model._standardize_user_data(
# --> 715         x, check_steps=True, steps_name='steps', steps=steps)
#     716     return predict_loop(
#     717         model,
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2470           feed_input_shapes,
#    2471           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2472           exception_prefix='input')
#    2473
#    2474     # Get typespecs for the input data and sanitize it if necessary.
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     572                              ': expected ' + names[i] + ' to have shape ' +
#     573                              str(shape) + ' but got array with shape ' +
# --> 574                              str(data_shape))
#     575   return data
#     576
#
# ValueError: Error when checking input: expected LR to have shape (None, None, 3) but got array with shape (240, 427, 4)

# %%
from ISR.models import RDN

# %%
rrdn = RDN(arch_params={'C': 3, 'D':10, 'G':64, 'G0':64, 'x':2})

# %%
rrdn.model.summary()
# Out:
# Model: "generator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# LR_input (InputLayer)           [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# Pre_blocks_conv (Conv2D)        (None, 200, 200, 64) 1792        LR_input[0][0]
# __________________________________________________________________________________________________
# F_1_1_1 (Conv2D)                (None, 200, 200, 64) 36928       Pre_blocks_conv[0][0]
# __________________________________________________________________________________________________
# F_1_1_1_Relu (Activation)       (None, 200, 200, 64) 0           F_1_1_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_1_1 (Concatenate)  (None, 200, 200, 128 0           Pre_blocks_conv[0][0]
#                                                                  F_1_1_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_1_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_1_1_1[0][0]
# __________________________________________________________________________________________________
# F_1_1_2_Relu (Activation)       (None, 200, 200, 64) 0           F_1_1_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_1_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_1_1_1[0][0]
#                                                                  F_1_1_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_1_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_1_1_2[0][0]
# __________________________________________________________________________________________________
# F_1_1_3_Relu (Activation)       (None, 200, 200, 64) 0           F_1_1_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_1_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_1_1_2[0][0]
#                                                                  F_1_1_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_1_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_1_1_3[0][0]
# __________________________________________________________________________________________________
# F_1_1_4_Relu (Activation)       (None, 200, 200, 64) 0           F_1_1_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_1_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_1_1_3[0][0]
#                                                                  F_1_1_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_1_1 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_1_1_4[0][0]
# __________________________________________________________________________________________________
# lambda_120 (Lambda)             (None, 200, 200, 64) 0           LFF_1_1[0][0]
# __________________________________________________________________________________________________
# LRL_1_1 (Add)                   (None, 200, 200, 64) 0           Pre_blocks_conv[0][0]
#                                                                  lambda_120[0][0]
# __________________________________________________________________________________________________
# F_1_2_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_1_1[0][0]
# __________________________________________________________________________________________________
# F_1_2_1_Relu (Activation)       (None, 200, 200, 64) 0           F_1_2_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_2_1 (Concatenate)  (None, 200, 200, 128 0           LRL_1_1[0][0]
#                                                                  F_1_2_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_2_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_1_2_1[0][0]
# __________________________________________________________________________________________________
# F_1_2_2_Relu (Activation)       (None, 200, 200, 64) 0           F_1_2_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_2_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_1_2_1[0][0]
#                                                                  F_1_2_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_2_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_1_2_2[0][0]
# __________________________________________________________________________________________________
# F_1_2_3_Relu (Activation)       (None, 200, 200, 64) 0           F_1_2_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_2_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_1_2_2[0][0]
#                                                                  F_1_2_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_2_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_1_2_3[0][0]
# __________________________________________________________________________________________________
# F_1_2_4_Relu (Activation)       (None, 200, 200, 64) 0           F_1_2_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_2_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_1_2_3[0][0]
#                                                                  F_1_2_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_1_2 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_1_2_4[0][0]
# __________________________________________________________________________________________________
# lambda_121 (Lambda)             (None, 200, 200, 64) 0           LFF_1_2[0][0]
# __________________________________________________________________________________________________
# LRL_1_2 (Add)                   (None, 200, 200, 64) 0           LRL_1_1[0][0]
#                                                                  lambda_121[0][0]
# __________________________________________________________________________________________________
# F_1_3_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_1_2[0][0]
# __________________________________________________________________________________________________
# F_1_3_1_Relu (Activation)       (None, 200, 200, 64) 0           F_1_3_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_3_1 (Concatenate)  (None, 200, 200, 128 0           LRL_1_2[0][0]
#                                                                  F_1_3_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_3_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_1_3_1[0][0]
# __________________________________________________________________________________________________
# F_1_3_2_Relu (Activation)       (None, 200, 200, 64) 0           F_1_3_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_3_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_1_3_1[0][0]
#                                                                  F_1_3_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_3_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_1_3_2[0][0]
# __________________________________________________________________________________________________
# F_1_3_3_Relu (Activation)       (None, 200, 200, 64) 0           F_1_3_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_3_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_1_3_2[0][0]
#                                                                  F_1_3_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_3_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_1_3_3[0][0]
# __________________________________________________________________________________________________
# F_1_3_4_Relu (Activation)       (None, 200, 200, 64) 0           F_1_3_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_3_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_1_3_3[0][0]
#                                                                  F_1_3_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_1_3 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_1_3_4[0][0]
# __________________________________________________________________________________________________
# lambda_122 (Lambda)             (None, 200, 200, 64) 0           LFF_1_3[0][0]
# __________________________________________________________________________________________________
# LRL_1_3 (Add)                   (None, 200, 200, 64) 0           LRL_1_2[0][0]
#                                                                  lambda_122[0][0]
# __________________________________________________________________________________________________
# lambda_123 (Lambda)             (None, 200, 200, 64) 0           LRL_1_3[0][0]
# __________________________________________________________________________________________________
# RRDB_1_out (Add)                (None, 200, 200, 64) 0           Pre_blocks_conv[0][0]
#                                                                  lambda_123[0][0]
# __________________________________________________________________________________________________
# F_2_1_1 (Conv2D)                (None, 200, 200, 64) 36928       RRDB_1_out[0][0]
# __________________________________________________________________________________________________
# F_2_1_1_Relu (Activation)       (None, 200, 200, 64) 0           F_2_1_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_1_1 (Concatenate)  (None, 200, 200, 128 0           RRDB_1_out[0][0]
#                                                                  F_2_1_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_1_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_2_1_1[0][0]
# __________________________________________________________________________________________________
# F_2_1_2_Relu (Activation)       (None, 200, 200, 64) 0           F_2_1_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_1_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_2_1_1[0][0]
#                                                                  F_2_1_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_1_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_2_1_2[0][0]
# __________________________________________________________________________________________________
# F_2_1_3_Relu (Activation)       (None, 200, 200, 64) 0           F_2_1_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_1_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_2_1_2[0][0]
#                                                                  F_2_1_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_1_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_2_1_3[0][0]
# __________________________________________________________________________________________________
# F_2_1_4_Relu (Activation)       (None, 200, 200, 64) 0           F_2_1_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_1_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_2_1_3[0][0]
#                                                                  F_2_1_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_2_1 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_2_1_4[0][0]
# __________________________________________________________________________________________________
# lambda_124 (Lambda)             (None, 200, 200, 64) 0           LFF_2_1[0][0]
# __________________________________________________________________________________________________
# LRL_2_1 (Add)                   (None, 200, 200, 64) 0           RRDB_1_out[0][0]
#                                                                  lambda_124[0][0]
# __________________________________________________________________________________________________
# F_2_2_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_2_1[0][0]
# __________________________________________________________________________________________________
# F_2_2_1_Relu (Activation)       (None, 200, 200, 64) 0           F_2_2_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_2_1 (Concatenate)  (None, 200, 200, 128 0           LRL_2_1[0][0]
#                                                                  F_2_2_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_2_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_2_2_1[0][0]
# __________________________________________________________________________________________________
# F_2_2_2_Relu (Activation)       (None, 200, 200, 64) 0           F_2_2_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_2_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_2_2_1[0][0]
#                                                                  F_2_2_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_2_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_2_2_2[0][0]
# __________________________________________________________________________________________________
# F_2_2_3_Relu (Activation)       (None, 200, 200, 64) 0           F_2_2_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_2_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_2_2_2[0][0]
#                                                                  F_2_2_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_2_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_2_2_3[0][0]
# __________________________________________________________________________________________________
# F_2_2_4_Relu (Activation)       (None, 200, 200, 64) 0           F_2_2_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_2_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_2_2_3[0][0]
#                                                                  F_2_2_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_2_2 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_2_2_4[0][0]
# __________________________________________________________________________________________________
# lambda_125 (Lambda)             (None, 200, 200, 64) 0           LFF_2_2[0][0]
# __________________________________________________________________________________________________
# LRL_2_2 (Add)                   (None, 200, 200, 64) 0           LRL_2_1[0][0]
#                                                                  lambda_125[0][0]
# __________________________________________________________________________________________________
# F_2_3_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_2_2[0][0]
# __________________________________________________________________________________________________
# F_2_3_1_Relu (Activation)       (None, 200, 200, 64) 0           F_2_3_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_3_1 (Concatenate)  (None, 200, 200, 128 0           LRL_2_2[0][0]
#                                                                  F_2_3_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_3_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_2_3_1[0][0]
# __________________________________________________________________________________________________
# F_2_3_2_Relu (Activation)       (None, 200, 200, 64) 0           F_2_3_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_3_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_2_3_1[0][0]
#                                                                  F_2_3_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_3_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_2_3_2[0][0]
# __________________________________________________________________________________________________
# F_2_3_3_Relu (Activation)       (None, 200, 200, 64) 0           F_2_3_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_3_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_2_3_2[0][0]
#                                                                  F_2_3_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_3_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_2_3_3[0][0]
# __________________________________________________________________________________________________
# F_2_3_4_Relu (Activation)       (None, 200, 200, 64) 0           F_2_3_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_3_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_2_3_3[0][0]
#                                                                  F_2_3_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_2_3 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_2_3_4[0][0]
# __________________________________________________________________________________________________
# lambda_126 (Lambda)             (None, 200, 200, 64) 0           LFF_2_3[0][0]
# __________________________________________________________________________________________________
# LRL_2_3 (Add)                   (None, 200, 200, 64) 0           LRL_2_2[0][0]
#                                                                  lambda_126[0][0]
# __________________________________________________________________________________________________
# lambda_127 (Lambda)             (None, 200, 200, 64) 0           LRL_2_3[0][0]
# __________________________________________________________________________________________________
# RRDB_2_out (Add)                (None, 200, 200, 64) 0           RRDB_1_out[0][0]
#                                                                  lambda_127[0][0]
# __________________________________________________________________________________________________
# F_3_1_1 (Conv2D)                (None, 200, 200, 64) 36928       RRDB_2_out[0][0]
# __________________________________________________________________________________________________
# F_3_1_1_Relu (Activation)       (None, 200, 200, 64) 0           F_3_1_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_1_1 (Concatenate)  (None, 200, 200, 128 0           RRDB_2_out[0][0]
#                                                                  F_3_1_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_1_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_3_1_1[0][0]
# __________________________________________________________________________________________________
# F_3_1_2_Relu (Activation)       (None, 200, 200, 64) 0           F_3_1_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_1_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_3_1_1[0][0]
#                                                                  F_3_1_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_1_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_3_1_2[0][0]
# __________________________________________________________________________________________________
# F_3_1_3_Relu (Activation)       (None, 200, 200, 64) 0           F_3_1_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_1_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_3_1_2[0][0]
#                                                                  F_3_1_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_1_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_3_1_3[0][0]
# __________________________________________________________________________________________________
# F_3_1_4_Relu (Activation)       (None, 200, 200, 64) 0           F_3_1_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_1_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_3_1_3[0][0]
#                                                                  F_3_1_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_3_1 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_3_1_4[0][0]
# __________________________________________________________________________________________________
# lambda_128 (Lambda)             (None, 200, 200, 64) 0           LFF_3_1[0][0]
# __________________________________________________________________________________________________
# LRL_3_1 (Add)                   (None, 200, 200, 64) 0           RRDB_2_out[0][0]
#                                                                  lambda_128[0][0]
# __________________________________________________________________________________________________
# F_3_2_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_3_1[0][0]
# __________________________________________________________________________________________________
# F_3_2_1_Relu (Activation)       (None, 200, 200, 64) 0           F_3_2_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_2_1 (Concatenate)  (None, 200, 200, 128 0           LRL_3_1[0][0]
#                                                                  F_3_2_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_2_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_3_2_1[0][0]
# __________________________________________________________________________________________________
# F_3_2_2_Relu (Activation)       (None, 200, 200, 64) 0           F_3_2_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_2_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_3_2_1[0][0]
#                                                                  F_3_2_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_2_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_3_2_2[0][0]
# __________________________________________________________________________________________________
# F_3_2_3_Relu (Activation)       (None, 200, 200, 64) 0           F_3_2_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_2_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_3_2_2[0][0]
#                                                                  F_3_2_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_2_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_3_2_3[0][0]
# __________________________________________________________________________________________________
# F_3_2_4_Relu (Activation)       (None, 200, 200, 64) 0           F_3_2_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_2_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_3_2_3[0][0]
#                                                                  F_3_2_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_3_2 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_3_2_4[0][0]
# __________________________________________________________________________________________________
# lambda_129 (Lambda)             (None, 200, 200, 64) 0           LFF_3_2[0][0]
# __________________________________________________________________________________________________
# LRL_3_2 (Add)                   (None, 200, 200, 64) 0           LRL_3_1[0][0]
#                                                                  lambda_129[0][0]
# __________________________________________________________________________________________________
# F_3_3_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_3_2[0][0]
# __________________________________________________________________________________________________
# F_3_3_1_Relu (Activation)       (None, 200, 200, 64) 0           F_3_3_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_3_1 (Concatenate)  (None, 200, 200, 128 0           LRL_3_2[0][0]
#                                                                  F_3_3_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_3_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_3_3_1[0][0]
# __________________________________________________________________________________________________
# F_3_3_2_Relu (Activation)       (None, 200, 200, 64) 0           F_3_3_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_3_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_3_3_1[0][0]
#                                                                  F_3_3_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_3_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_3_3_2[0][0]
# __________________________________________________________________________________________________
# F_3_3_3_Relu (Activation)       (None, 200, 200, 64) 0           F_3_3_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_3_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_3_3_2[0][0]
#                                                                  F_3_3_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_3_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_3_3_3[0][0]
# __________________________________________________________________________________________________
# F_3_3_4_Relu (Activation)       (None, 200, 200, 64) 0           F_3_3_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_3_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_3_3_3[0][0]
#                                                                  F_3_3_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_3_3 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_3_3_4[0][0]
# __________________________________________________________________________________________________
# lambda_130 (Lambda)             (None, 200, 200, 64) 0           LFF_3_3[0][0]
# __________________________________________________________________________________________________
# LRL_3_3 (Add)                   (None, 200, 200, 64) 0           LRL_3_2[0][0]
#                                                                  lambda_130[0][0]
# __________________________________________________________________________________________________
# lambda_131 (Lambda)             (None, 200, 200, 64) 0           LRL_3_3[0][0]
# __________________________________________________________________________________________________
# RRDB_3_out (Add)                (None, 200, 200, 64) 0           RRDB_2_out[0][0]
#                                                                  lambda_131[0][0]
# __________________________________________________________________________________________________
# F_4_1_1 (Conv2D)                (None, 200, 200, 64) 36928       RRDB_3_out[0][0]
# __________________________________________________________________________________________________
# F_4_1_1_Relu (Activation)       (None, 200, 200, 64) 0           F_4_1_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_1_1 (Concatenate)  (None, 200, 200, 128 0           RRDB_3_out[0][0]
#                                                                  F_4_1_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_1_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_4_1_1[0][0]
# __________________________________________________________________________________________________
# F_4_1_2_Relu (Activation)       (None, 200, 200, 64) 0           F_4_1_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_1_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_4_1_1[0][0]
#                                                                  F_4_1_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_1_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_4_1_2[0][0]
# __________________________________________________________________________________________________
# F_4_1_3_Relu (Activation)       (None, 200, 200, 64) 0           F_4_1_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_1_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_4_1_2[0][0]
#                                                                  F_4_1_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_1_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_4_1_3[0][0]
# __________________________________________________________________________________________________
# F_4_1_4_Relu (Activation)       (None, 200, 200, 64) 0           F_4_1_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_1_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_4_1_3[0][0]
#                                                                  F_4_1_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_4_1 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_4_1_4[0][0]
# __________________________________________________________________________________________________
# lambda_132 (Lambda)             (None, 200, 200, 64) 0           LFF_4_1[0][0]
# __________________________________________________________________________________________________
# LRL_4_1 (Add)                   (None, 200, 200, 64) 0           RRDB_3_out[0][0]
#                                                                  lambda_132[0][0]
# __________________________________________________________________________________________________
# F_4_2_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_4_1[0][0]
# __________________________________________________________________________________________________
# F_4_2_1_Relu (Activation)       (None, 200, 200, 64) 0           F_4_2_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_2_1 (Concatenate)  (None, 200, 200, 128 0           LRL_4_1[0][0]
#                                                                  F_4_2_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_2_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_4_2_1[0][0]
# __________________________________________________________________________________________________
# F_4_2_2_Relu (Activation)       (None, 200, 200, 64) 0           F_4_2_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_2_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_4_2_1[0][0]
#                                                                  F_4_2_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_2_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_4_2_2[0][0]
# __________________________________________________________________________________________________
# F_4_2_3_Relu (Activation)       (None, 200, 200, 64) 0           F_4_2_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_2_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_4_2_2[0][0]
#                                                                  F_4_2_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_2_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_4_2_3[0][0]
# __________________________________________________________________________________________________
# F_4_2_4_Relu (Activation)       (None, 200, 200, 64) 0           F_4_2_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_2_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_4_2_3[0][0]
#                                                                  F_4_2_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_4_2 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_4_2_4[0][0]
# __________________________________________________________________________________________________
# lambda_133 (Lambda)             (None, 200, 200, 64) 0           LFF_4_2[0][0]
# __________________________________________________________________________________________________
# LRL_4_2 (Add)                   (None, 200, 200, 64) 0           LRL_4_1[0][0]
#                                                                  lambda_133[0][0]
# __________________________________________________________________________________________________
# F_4_3_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_4_2[0][0]
# __________________________________________________________________________________________________
# F_4_3_1_Relu (Activation)       (None, 200, 200, 64) 0           F_4_3_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_3_1 (Concatenate)  (None, 200, 200, 128 0           LRL_4_2[0][0]
#                                                                  F_4_3_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_3_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_4_3_1[0][0]
# __________________________________________________________________________________________________
# F_4_3_2_Relu (Activation)       (None, 200, 200, 64) 0           F_4_3_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_3_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_4_3_1[0][0]
#                                                                  F_4_3_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_3_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_4_3_2[0][0]
# __________________________________________________________________________________________________
# F_4_3_3_Relu (Activation)       (None, 200, 200, 64) 0           F_4_3_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_3_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_4_3_2[0][0]
#                                                                  F_4_3_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_3_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_4_3_3[0][0]
# __________________________________________________________________________________________________
# F_4_3_4_Relu (Activation)       (None, 200, 200, 64) 0           F_4_3_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_3_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_4_3_3[0][0]
#                                                                  F_4_3_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_4_3 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_4_3_4[0][0]
# __________________________________________________________________________________________________
# lambda_134 (Lambda)             (None, 200, 200, 64) 0           LFF_4_3[0][0]
# __________________________________________________________________________________________________
# LRL_4_3 (Add)                   (None, 200, 200, 64) 0           LRL_4_2[0][0]
#                                                                  lambda_134[0][0]
# __________________________________________________________________________________________________
# lambda_135 (Lambda)             (None, 200, 200, 64) 0           LRL_4_3[0][0]
# __________________________________________________________________________________________________
# RRDB_4_out (Add)                (None, 200, 200, 64) 0           RRDB_3_out[0][0]
#                                                                  lambda_135[0][0]
# __________________________________________________________________________________________________
# F_5_1_1 (Conv2D)                (None, 200, 200, 64) 36928       RRDB_4_out[0][0]
# __________________________________________________________________________________________________
# F_5_1_1_Relu (Activation)       (None, 200, 200, 64) 0           F_5_1_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_1_1 (Concatenate)  (None, 200, 200, 128 0           RRDB_4_out[0][0]
#                                                                  F_5_1_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_1_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_5_1_1[0][0]
# __________________________________________________________________________________________________
# F_5_1_2_Relu (Activation)       (None, 200, 200, 64) 0           F_5_1_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_1_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_5_1_1[0][0]
#                                                                  F_5_1_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_1_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_5_1_2[0][0]
# __________________________________________________________________________________________________
# F_5_1_3_Relu (Activation)       (None, 200, 200, 64) 0           F_5_1_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_1_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_5_1_2[0][0]
#                                                                  F_5_1_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_1_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_5_1_3[0][0]
# __________________________________________________________________________________________________
# F_5_1_4_Relu (Activation)       (None, 200, 200, 64) 0           F_5_1_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_1_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_5_1_3[0][0]
#                                                                  F_5_1_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_5_1 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_5_1_4[0][0]
# __________________________________________________________________________________________________
# lambda_136 (Lambda)             (None, 200, 200, 64) 0           LFF_5_1[0][0]
# __________________________________________________________________________________________________
# LRL_5_1 (Add)                   (None, 200, 200, 64) 0           RRDB_4_out[0][0]
#                                                                  lambda_136[0][0]
# __________________________________________________________________________________________________
# F_5_2_1 (Conv2D)                (None, 200, 200, 64) 36928       LRL_5_1[0][0]
# __________________________________________________________________________________________________
# ...
# F_9_3_1_Relu (Activation)       (None, 200, 200, 64) 0           F_9_3_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_3_1 (Concatenate)  (None, 200, 200, 128 0           LRL_9_2[0][0]
#                                                                  F_9_3_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_3_2 (Conv2D)                (None, 200, 200, 64) 73792       RDB_Concat_9_3_1[0][0]
# __________________________________________________________________________________________________
# F_9_3_2_Relu (Activation)       (None, 200, 200, 64) 0           F_9_3_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_3_2 (Concatenate)  (None, 200, 200, 192 0           RDB_Concat_9_3_1[0][0]
#                                                                  F_9_3_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_3_3 (Conv2D)                (None, 200, 200, 64) 110656      RDB_Concat_9_3_2[0][0]
# __________________________________________________________________________________________________
# F_9_3_3_Relu (Activation)       (None, 200, 200, 64) 0           F_9_3_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_3_3 (Concatenate)  (None, 200, 200, 256 0           RDB_Concat_9_3_2[0][0]
#                                                                  F_9_3_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_3_4 (Conv2D)                (None, 200, 200, 64) 147520      RDB_Concat_9_3_3[0][0]
# __________________________________________________________________________________________________
# F_9_3_4_Relu (Activation)       (None, 200, 200, 64) 0           F_9_3_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_3_4 (Concatenate)  (None, 200, 200, 320 0           RDB_Concat_9_3_3[0][0]
#                                                                  F_9_3_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_9_3 (Conv2D)                (None, 200, 200, 64) 184384      RDB_Concat_9_3_4[0][0]
# __________________________________________________________________________________________________
# lambda_154 (Lambda)             (None, 200, 200, 64) 0           LFF_9_3[0][0]
# __________________________________________________________________________________________________
# LRL_9_3 (Add)                   (None, 200, 200, 64) 0           LRL_9_2[0][0]
#                                                                  lambda_154[0][0]
# __________________________________________________________________________________________________
# lambda_155 (Lambda)             (None, 200, 200, 64) 0           LRL_9_3[0][0]
# __________________________________________________________________________________________________
# RRDB_9_out (Add)                (None, 200, 200, 64) 0           RRDB_8_out[0][0]
#                                                                  lambda_155[0][0]
# __________________________________________________________________________________________________
# F_10_1_1 (Conv2D)               (None, 200, 200, 64) 36928       RRDB_9_out[0][0]
# __________________________________________________________________________________________________
# F_10_1_1_Relu (Activation)      (None, 200, 200, 64) 0           F_10_1_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_1_1 (Concatenate) (None, 200, 200, 128 0           RRDB_9_out[0][0]
#                                                                  F_10_1_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_1_2 (Conv2D)               (None, 200, 200, 64) 73792       RDB_Concat_10_1_1[0][0]
# __________________________________________________________________________________________________
# F_10_1_2_Relu (Activation)      (None, 200, 200, 64) 0           F_10_1_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_1_2 (Concatenate) (None, 200, 200, 192 0           RDB_Concat_10_1_1[0][0]
#                                                                  F_10_1_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_1_3 (Conv2D)               (None, 200, 200, 64) 110656      RDB_Concat_10_1_2[0][0]
# __________________________________________________________________________________________________
# F_10_1_3_Relu (Activation)      (None, 200, 200, 64) 0           F_10_1_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_1_3 (Concatenate) (None, 200, 200, 256 0           RDB_Concat_10_1_2[0][0]
#                                                                  F_10_1_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_1_4 (Conv2D)               (None, 200, 200, 64) 147520      RDB_Concat_10_1_3[0][0]
# __________________________________________________________________________________________________
# F_10_1_4_Relu (Activation)      (None, 200, 200, 64) 0           F_10_1_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_1_4 (Concatenate) (None, 200, 200, 320 0           RDB_Concat_10_1_3[0][0]
#                                                                  F_10_1_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_10_1 (Conv2D)               (None, 200, 200, 64) 184384      RDB_Concat_10_1_4[0][0]
# __________________________________________________________________________________________________
# lambda_156 (Lambda)             (None, 200, 200, 64) 0           LFF_10_1[0][0]
# __________________________________________________________________________________________________
# LRL_10_1 (Add)                  (None, 200, 200, 64) 0           RRDB_9_out[0][0]
#                                                                  lambda_156[0][0]
# __________________________________________________________________________________________________
# F_10_2_1 (Conv2D)               (None, 200, 200, 64) 36928       LRL_10_1[0][0]
# __________________________________________________________________________________________________
# F_10_2_1_Relu (Activation)      (None, 200, 200, 64) 0           F_10_2_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_2_1 (Concatenate) (None, 200, 200, 128 0           LRL_10_1[0][0]
#                                                                  F_10_2_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_2_2 (Conv2D)               (None, 200, 200, 64) 73792       RDB_Concat_10_2_1[0][0]
# __________________________________________________________________________________________________
# F_10_2_2_Relu (Activation)      (None, 200, 200, 64) 0           F_10_2_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_2_2 (Concatenate) (None, 200, 200, 192 0           RDB_Concat_10_2_1[0][0]
#                                                                  F_10_2_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_2_3 (Conv2D)               (None, 200, 200, 64) 110656      RDB_Concat_10_2_2[0][0]
# __________________________________________________________________________________________________
# F_10_2_3_Relu (Activation)      (None, 200, 200, 64) 0           F_10_2_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_2_3 (Concatenate) (None, 200, 200, 256 0           RDB_Concat_10_2_2[0][0]
#                                                                  F_10_2_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_2_4 (Conv2D)               (None, 200, 200, 64) 147520      RDB_Concat_10_2_3[0][0]
# __________________________________________________________________________________________________
# F_10_2_4_Relu (Activation)      (None, 200, 200, 64) 0           F_10_2_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_2_4 (Concatenate) (None, 200, 200, 320 0           RDB_Concat_10_2_3[0][0]
#                                                                  F_10_2_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_10_2 (Conv2D)               (None, 200, 200, 64) 184384      RDB_Concat_10_2_4[0][0]
# __________________________________________________________________________________________________
# lambda_157 (Lambda)             (None, 200, 200, 64) 0           LFF_10_2[0][0]
# __________________________________________________________________________________________________
# LRL_10_2 (Add)                  (None, 200, 200, 64) 0           LRL_10_1[0][0]
#                                                                  lambda_157[0][0]
# __________________________________________________________________________________________________
# F_10_3_1 (Conv2D)               (None, 200, 200, 64) 36928       LRL_10_2[0][0]
# __________________________________________________________________________________________________
# F_10_3_1_Relu (Activation)      (None, 200, 200, 64) 0           F_10_3_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_3_1 (Concatenate) (None, 200, 200, 128 0           LRL_10_2[0][0]
#                                                                  F_10_3_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_3_2 (Conv2D)               (None, 200, 200, 64) 73792       RDB_Concat_10_3_1[0][0]
# __________________________________________________________________________________________________
# F_10_3_2_Relu (Activation)      (None, 200, 200, 64) 0           F_10_3_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_3_2 (Concatenate) (None, 200, 200, 192 0           RDB_Concat_10_3_1[0][0]
#                                                                  F_10_3_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_3_3 (Conv2D)               (None, 200, 200, 64) 110656      RDB_Concat_10_3_2[0][0]
# __________________________________________________________________________________________________
# F_10_3_3_Relu (Activation)      (None, 200, 200, 64) 0           F_10_3_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_3_3 (Concatenate) (None, 200, 200, 256 0           RDB_Concat_10_3_2[0][0]
#                                                                  F_10_3_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_3_4 (Conv2D)               (None, 200, 200, 64) 147520      RDB_Concat_10_3_3[0][0]
# __________________________________________________________________________________________________
# F_10_3_4_Relu (Activation)      (None, 200, 200, 64) 0           F_10_3_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_3_4 (Concatenate) (None, 200, 200, 320 0           RDB_Concat_10_3_3[0][0]
#                                                                  F_10_3_4_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_10_3 (Conv2D)               (None, 200, 200, 64) 184384      RDB_Concat_10_3_4[0][0]
# __________________________________________________________________________________________________
# lambda_158 (Lambda)             (None, 200, 200, 64) 0           LFF_10_3[0][0]
# __________________________________________________________________________________________________
# LRL_10_3 (Add)                  (None, 200, 200, 64) 0           LRL_10_2[0][0]
#                                                                  lambda_158[0][0]
# __________________________________________________________________________________________________
# lambda_159 (Lambda)             (None, 200, 200, 64) 0           LRL_10_3[0][0]
# __________________________________________________________________________________________________
# RRDB_10_out (Add)               (None, 200, 200, 64) 0           RRDB_9_out[0][0]
#                                                                  lambda_159[0][0]
# __________________________________________________________________________________________________
# post_blocks_conv (Conv2D)       (None, 200, 200, 64) 36928       RRDB_10_out[0][0]
# __________________________________________________________________________________________________
# GRL (Add)                       (None, 200, 200, 64) 0           post_blocks_conv[0][0]
#                                                                  Pre_blocks_conv[0][0]
# __________________________________________________________________________________________________
# PreShuffle (Conv2D)             (None, 200, 200, 12) 6924        GRL[0][0]
# __________________________________________________________________________________________________
# PixelShuffle (Lambda)           (None, 400, 400, 3)  0           PreShuffle[0][0]
# __________________________________________________________________________________________________
# SR (Conv2D)                     (None, 400, 400, 3)  84          PixelShuffle[0][0]
# ==================================================================================================
# Total params: 16,644,128
# Trainable params: 16,644,128
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
fashion_mnist = tf.keras.datasets.mnist.load_data()

# %%
cifar100 = tf.keras.datasets.cifar100.load_data()
(train_image, train_label), (test_image, test_label) = cifar100

# %%
plt.imshow(train_image[52])

# %%
from ISR.utils import image_processing as im

# %%
a = im.split_image_into_overlapping_patches(train_image, 32, 24)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-aa5f06552a0a> in <module>
# ----> 1 a = im.split_image_into_overlapping_patches(train_image, 32, 24)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\ISR\utils\image_processing.py in split_image_into_overlapping_patches(image_array, patch_size, padding_size)
#      55     """
#      56
# ---> 57     xmax, ymax, _ = image_array.shape
#      58     x_remainder = xmax % patch_size
#      59     y_remainder = ymax % patch_size
#
# ValueError: too many values to unpack (expected 3)

# %%
train_image[52].shape
# Out:
# (32, 32, 3)

# %%
im.process_array(train_image).shape
# Out:
# (1, 50000, 32, 32, 3)

# %%
plt.imshow(a[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-5e0ed0962885> in <module>
# ----> 1 plt.imshow(a[0])
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5613                               resample=resample, **kwargs)
#    5614
# -> 5615         im.set_data(X)
#    5616         im.set_alpha(alpha)
#    5617         if im.get_clip_path() is None:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     697                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     698             raise TypeError("Invalid shape {} for image data"
# --> 699                             .format(self._A.shape))
#     700
#     701         if self._A.ndim == 3:
#
# TypeError: Invalid shape (1, 80, 80, 3) for image data

# %%
b=im.pad_patch(train_image[52], 10, 3)

# %%
b.shape
plt.imshow(b)

# %%
plt.imshow(train_image[52])

# %%
c = im.split_image_into_overlapping_patches(b, 32, 10)
len(c)
# Out:
# 2

# %%
c[1]
# Out:
# (84, 84, 3)

# %%
img_raw = tf.io.read_file("section8-image.png")
img_tensor = tf.image.decode_image(img_raw)

# %%
print(img_tensor)
# Out:
# tf.Tensor(
# [[[ 31  62   6]
#   [ 31  58   6]
#   [ 32  59   6]
#   ...
#   [ 19  14   6]
#   [ 19  14   6]
#   [ 21  13   6]]
#
#  [[ 31  64   6]
#   [ 25  60   6]
#   [ 34  66   6]
#   ...
#   [ 12  10   6]
#   [ 15  11   6]
#   [ 21  14   6]]
#
#  [[ 33  64   6]
#   [ 36  64  10]
#   [ 45  73  16]
#   ...
#   [ 15  11   6]
#   [ 16  12   6]
#   [ 24  15   6]]
#
#  ...
#
#  [[243  82  63]
#   [196  70  30]
#   [100  29  10]
#   ...
#   [ 27  33   6]
#   [ 31  31   6]
#   [ 39  34   6]]
#
#  [[236  62  53]
#   [227  78  44]
#   [136  40   6]
#   ...
#   [ 24  35   6]
#   [ 26  35   6]
#   [ 31  32   6]]
#
#  [[195  34  26]
#   [231  62  48]
#   [204  70  29]
#   ...
#   [ 24  36   6]
#   [ 26  36   6]
#   [ 29  36   6]]], shape=(256, 256, 3), dtype=uint8)

# %%
plt.imshow(img_tensor)
